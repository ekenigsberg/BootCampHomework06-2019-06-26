# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import openweathermapy.core as owm
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Create settings dictionary
dictStgs = {'units': 'imperial', 'appid': api_key}

# Output File (CSV)
strOutput = "output_data/cities.csv"

# Range of latitudes and longitudes
tupLatRng = (-90, 90)
tupLngRng = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lstCoord = []
lstCity = []

# Create a set of random lat and lng combinations
lstLat = np.random.uniform(low=-90.000, high=90.000, size=1500)
lstLng = np.random.uniform(low=-180.000, high=180.000, size=1500)
ltupCoord = zip(lstLat, lstLng)

# Identify nearest city for each lat, lng combination
for tupLatLng in ltupCoord:
    strCity = citipy.nearest_city(tupLatLng[0], tupLatLng[1]).city_name
    
    # If the city is unique, then add it to our cities list
    if strCity not in lstCity:
        lstCity.append(strCity)

# Print the city count to confirm sufficient count
len(lstCity)
# Out:
# 588

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
strFoo = owm.get_current(lstCity[0], **dictStgs)
print(strFoo)
# Out:
# {'coord': {'lon': 115.35, 'lat': -33.64}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 51.01, 'pressure': 1015, 'humidity': 60, 'temp_min': 50, 'temp_max': 52}, 'wind': {'speed': 6.38, 'deg': 104.139}, 'clouds': {'all': 12}, 'dt': 1562072734, 'sys': {'type': 3, 'id': 2011706, 'message': 0.0076, 'country': 'AU', 'sunrise': 1562023424, 'sunset': 1562059258}, 'timezone': 28800, 'id': 2075265, 'name': 'Busselton', 'cod': 200}

# %%
# check weather in each city
lstCityWthr = []
for i in range(len(lstCity)):
    strCity = lstCity[i]
    try:
        dictResult = owm.get_current(strCity, **dictStgs)
        lstCityWthr.append(dictResult)
        strID = dictResult['id']
        print(f'{str(i).zfill(3)}) Just retrieved weather for {strCity} (ID {strID}).')
    except Exception as e:
        lstCityWthr.append('#N/A')
        print(f'{str(i).zfill(3)}) Couldn\'t retrieve weather for {strCity} ({e}).')
# Out:
# 000) Just retrieved weather for busselton (ID 2075265).
# 001) Couldn't retrieve weather for belushya guba (HTTP Error 404: Not Found).
# 002) Couldn't retrieve weather for rungata (HTTP Error 404: Not Found).
# 003) Just retrieved weather for jumla (ID 1283285).
# 004) Just retrieved weather for ribeira grande (ID 3372707).
# 005) Just retrieved weather for ilhabela (ID 3461425).
# 006) Just retrieved weather for mahebourg (ID 934322).
# 007) Just retrieved weather for punta arenas (ID 3874787).
# 008) Just retrieved weather for rikitea (ID 4030556).
# 009) Just retrieved weather for jamestown (ID 2069194).
# 010) Couldn't retrieve weather for tahta (HTTP Error 404: Not Found).
# 011) Just retrieved weather for dunedin (ID 2191562).
# 012) Couldn't retrieve weather for tsihombe (HTTP Error 404: Not Found).
# 013) Just retrieved weather for nioro (ID 2413070).
# 014) Just retrieved weather for dikson (ID 1507390).
# 015) Just retrieved weather for angoche (ID 1052944).
# 016) Just retrieved weather for margate (ID 2158744).
# 017) Just retrieved weather for puerto ayora (ID 3652764).
# 018) Just retrieved weather for parnamirim (ID 3392998).
# 019) Just retrieved weather for labuhan (ID 1641899).
# 020) Just retrieved weather for butaritari (ID 2110227).
# 021) Just retrieved weather for victoria (ID 1733782).
# 022) Just retrieved weather for saint-joseph (ID 3037456).
# 023) Just retrieved weather for albany (ID 5106834).
# 024) Just retrieved weather for vaini (ID 1273574).
# 025) Just retrieved weather for hilo (ID 5855927).
# 026) Just retrieved weather for bredasdorp (ID 1015776).
# 027) Just retrieved weather for hasaki (ID 2112802).
# 028) Just retrieved weather for ushuaia (ID 3833367).
# 029) Just retrieved weather for esperance (ID 2071860).
# 030) Just retrieved weather for darnah (ID 87205).
# 031) Couldn't retrieve weather for urdzhar (HTTP Error 404: Not Found).
# 032) Just retrieved weather for goderich (ID 5962442).
# 033) Just retrieved weather for harper (ID 4696310).
# 034) Just retrieved weather for port alfred (ID 964432).
# 035) Couldn't retrieve weather for tumannyy (HTTP Error 404: Not Found).
# 036) Just retrieved weather for isangel (ID 2136825).
# 037) Just retrieved weather for khatanga (ID 2022572).
# 038) Just retrieved weather for carnarvon (ID 1014034).
# 039) Just retrieved weather for bluff (ID 2175403).
# 040) Just retrieved weather for mataura (ID 6201424).
# 041) Just retrieved weather for nome (ID 4732862).
# 042) Couldn't retrieve weather for zhanatas (HTTP Error 404: Not Found).
# 043) Just retrieved weather for san andres (ID 1690438).
# 044) Just retrieved weather for hobart (ID 2163355).
# 045) Couldn't retrieve weather for mergui (HTTP Error 404: Not Found).
# 046) Just retrieved weather for castro (ID 3896218).
# 047) Just retrieved weather for makanya (ID 155187).
# 048) Just retrieved weather for georgetown (ID 3378644).
# 049) Just retrieved weather for east london (ID 1006984).
# 050) Just retrieved weather for hun (ID 2790471).
# 051) Just retrieved weather for katsuura (ID 1865309).
# 052) Just retrieved weather for nakhon phanom (ID 1608531).
# 053) Just retrieved weather for tiksi (ID 2015306).
# 054) Just retrieved weather for saint george (ID 262462).
# 055) Just retrieved weather for paita (ID 3694112).
# 056) Just retrieved weather for kloulklubed (ID 7671223).
# 057) Just retrieved weather for tecoanapa (ID 3532499).
# 058) Just retrieved weather for nanortalik (ID 3421765).
# 059) Just retrieved weather for lompoc (ID 5367788).
# 060) Just retrieved weather for grindavik (ID 3416888).
# 061) Just retrieved weather for new norfolk (ID 2155415).
# 062) Just retrieved weather for karpathos (ID 260895).
# 063) Just retrieved weather for shimoda (ID 1852357).
# 064) Just retrieved weather for chapayeve (ID 710940).
# 065) Just retrieved weather for trat (ID 1605279).
# 066) Couldn't retrieve weather for toungoo (HTTP Error 404: Not Found).
# 067) Couldn't retrieve weather for shibarghan (HTTP Error 404: Not Found).
# 068) Just retrieved weather for san patricio (ID 3437029).
# 069) Just retrieved weather for sao filipe (ID 3374210).
# 070) Just retrieved weather for north platte (ID 5697939).
# 071) Just retrieved weather for lypova dolyna (ID 703015).
# 072) Just retrieved weather for barrow (ID 3833859).
# 073) Just retrieved weather for kahului (ID 5847411).
# 074) Just retrieved weather for matara (ID 425378).
# 075) Just retrieved weather for sobolevo (ID 525426).
# 076) Just retrieved weather for tagusao (ID 1684245).
# 077) Just retrieved weather for emerald (ID 2167426).
# 078) Just retrieved weather for fairbanks (ID 5861897).
# 079) Just retrieved weather for paamiut (ID 3421193).
# 080) Just retrieved weather for upernavik (ID 3418910).
# 081) Just retrieved weather for bethel (ID 5880568).
# 082) Just retrieved weather for norman wells (ID 6089245).
# 083) Just retrieved weather for comodoro rivadavia (ID 3860443).
# 084) Just retrieved weather for hithadhoo (ID 1282256).
# 085) Just retrieved weather for srednekolymsk (ID 2121025).
# 086) Just retrieved weather for beringovskiy (ID 2126710).
# 087) Just retrieved weather for madang (ID 7413703).
# 088) Just retrieved weather for atuona (ID 4020109).
# 089) Just retrieved weather for anadyr (ID 2127202).
# 090) Just retrieved weather for cayenne (ID 3382160).
# 091) Couldn't retrieve weather for krasnoselkup (HTTP Error 404: Not Found).
# 092) Just retrieved weather for luderitz (ID 3355672).
# 093) Just retrieved weather for bambous virieux (ID 1106677).
# 094) Just retrieved weather for kavieng (ID 2094342).
# 095) Just retrieved weather for kapaa (ID 5848280).
# 096) Just retrieved weather for cadillac (ID 4987617).
# 097) Just retrieved weather for severo-kurilsk (ID 2121385).
# 098) Just retrieved weather for saldanha (ID 2737599).
# 099) Just retrieved weather for boyuibe (ID 3923015).
# 100) Just retrieved weather for mar del plata (ID 3863379).
# 101) Just retrieved weather for mayo (ID 6068416).
# 102) Just retrieved weather for sept-iles (ID 6144312).
# 103) Just retrieved weather for carbonia (ID 2525362).
# 104) Just retrieved weather for sao bernardo (ID 3388949).
# 105) Just retrieved weather for diego de almagro (ID 3892454).
# 106) Couldn't retrieve weather for viligili (HTTP Error 404: Not Found).
# 107) Just retrieved weather for kachug (ID 2023333).
# 108) Just retrieved weather for saskylakh (ID 2017155).
# 109) Just retrieved weather for mumford (ID 2297810).
# 110) Just retrieved weather for yellowknife (ID 6185377).
# 111) Just retrieved weather for klaksvik (ID 2618795).
# 112) Just retrieved weather for plyussa (ID 508743).
# 113) Just retrieved weather for gazanjyk (ID 161974).
# 114) Just retrieved weather for jurm (ID 1139085).
# 115) Just retrieved weather for half moon bay (ID 5354943).
# 116) Just retrieved weather for tuktoyaktuk (ID 6170031).
# 117) Couldn't retrieve weather for camana (HTTP Error 404: Not Found).
# 118) Just retrieved weather for frontera (ID 3527545).
# 119) Just retrieved weather for qaanaaq (ID 3831208).
# 120) Just retrieved weather for chuy (ID 3443061).
# 121) Just retrieved weather for sola (ID 151211).
# 122) Just retrieved weather for avarua (ID 4035715).
# 123) Just retrieved weather for provideniya (ID 4031574).
# 124) Just retrieved weather for chokurdakh (ID 2126123).
# 125) Just retrieved weather for gudalur (ID 1262284).
# 126) Just retrieved weather for leh (ID 1264976).
# 127) Just retrieved weather for faya (ID 110690).
# 128) Couldn't retrieve weather for karaul (HTTP Error 404: Not Found).
# 129) Just retrieved weather for areosa (ID 2742765).
# 130) Just retrieved weather for nizhnyaya tavda (ID 1497376).
# 131) Just retrieved weather for airai (ID 1651810).
# 132) Just retrieved weather for narsaq (ID 3421719).
# 133) Just retrieved weather for camalu (ID 3979216).
# 134) Just retrieved weather for pevek (ID 2122090).
# 135) Just retrieved weather for san cristobal (ID 3609418).
# 136) Couldn't retrieve weather for kemijarvi (HTTP Error 404: Not Found).
# 137) Couldn't retrieve weather for barentsburg (HTTP Error 404: Not Found).
# 138) Just retrieved weather for lekoni (ID 2399831).
# 139) Just retrieved weather for mount gambier (ID 2156643).
# 140) Just retrieved weather for toma (ID 2354265).
# 141) Couldn't retrieve weather for karauzyak (HTTP Error 404: Not Found).
# 142) Just retrieved weather for taoudenni (ID 2450173).
# 143) Just retrieved weather for olindina (ID 3455913).
# 144) Couldn't retrieve weather for pahuatlan (HTTP Error 404: Not Found).
# 145) Just retrieved weather for indianola (ID 5697383).
# 146) Just retrieved weather for omsukchan (ID 2122493).
# 147) Just retrieved weather for sambava (ID 1056899).
# 148) Just retrieved weather for souillac (ID 3026644).
# 149) Just retrieved weather for ponta do sol (ID 3453439).
# 150) Just retrieved weather for lima (ID 3936456).
# 151) Just retrieved weather for hwange (ID 889942).
# 152) Couldn't retrieve weather for kadykchan (HTTP Error 404: Not Found).
# 153) Just retrieved weather for naryan-mar (ID 523392).
# 154) Just retrieved weather for teshie (ID 2306104).
# 155) Just retrieved weather for vila franca do campo (ID 3372472).
# 156) Just retrieved weather for khudumelapye (ID 933562).
# 157) Just retrieved weather for lehututu (ID 933548).
# 158) Just retrieved weather for sao joao da barra (ID 3448903).
# 159) Just retrieved weather for otavi (ID 3353934).
# 160) Couldn't retrieve weather for nizhneyansk (HTTP Error 404: Not Found).
# 161) Just retrieved weather for bodden town (ID 3580733).
# 162) Just retrieved weather for bati (ID 342641).
# 163) Just retrieved weather for bahia honda (ID 3567995).
# 164) Just retrieved weather for san onofre (ID 3669218).
# 165) Just retrieved weather for makakilo city (ID 5850554).
# 166) Just retrieved weather for sungaipenuh (ID 1625929).
# 167) Just retrieved weather for juruti (ID 3396979).
# 168) Just retrieved weather for lorengau (ID 2092164).
# 169) Couldn't retrieve weather for mys shmidta (HTTP Error 404: Not Found).
# 170) Just retrieved weather for tavda (ID 1489962).
# 171) Just retrieved weather for cape town (ID 3369157).
# 172) Just retrieved weather for kitaibaraki (ID 2112232).
# 173) Couldn't retrieve weather for chagda (HTTP Error 404: Not Found).
# 174) Just retrieved weather for ron phibun (ID 1150921).
# 175) Couldn't retrieve weather for vaitupu (HTTP Error 404: Not Found).
# 176) Just retrieved weather for hamilton (ID 5969785).
# 177) Just retrieved weather for chipinge (ID 893549).
# 178) Just retrieved weather for yerofey pavlovich (ID 2012938).
# 179) Just retrieved weather for clyde river (ID 5924351).
# 180) Just retrieved weather for havoysund (ID 779622).
# 181) Just retrieved weather for abbotsford (ID 5881791).
# 182) Just retrieved weather for ust-nera (ID 2120048).
# 183) Just retrieved weather for itaituba (ID 3397967).
# 184) Just retrieved weather for broken hill (ID 2173911).
# 185) Just retrieved weather for galveston (ID 4920577).
# 186) Just retrieved weather for nizwa (ID 286987).
# 187) Just retrieved weather for iqaluit (ID 5983720).
# 188) Just retrieved weather for thompson (ID 6165406).
# 189) Just retrieved weather for letlhakeng (ID 933534).
# 190) Just retrieved weather for mariental (ID 3458826).
# 191) Just retrieved weather for talnakh (ID 1490256).
# 192) Just retrieved weather for nikolskoye (ID 546105).
# 193) Just retrieved weather for san quintin (ID 1688687).
# 194) Just retrieved weather for shumskiy (ID 1491977).
# 195) Just retrieved weather for pinsk (ID 623549).
# 196) Just retrieved weather for porto novo (ID 6322184).
# 197) Just retrieved weather for abaete (ID 3473267).
# 198) Just retrieved weather for faanui (ID 4034551).
# 199) Just retrieved weather for port elizabeth (ID 4501427).
# 200) Just retrieved weather for leningradskiy (ID 2123814).
# 201) Just retrieved weather for beloha (ID 1067565).
# 202) Just retrieved weather for paris (ID 2988507).
# 203) Just retrieved weather for la ronge (ID 6050066).
# 204) Just retrieved weather for puerto ayacucho (ID 3629710).
# 205) Just retrieved weather for terrace (ID 6162949).
# 206) Just retrieved weather for birin (ID 1283334).
# 207) Just retrieved weather for trelew (ID 3833883).
# 208) Just retrieved weather for saint-philippe (ID 6138908).
# 209) Just retrieved weather for tuatapere (ID 2180815).
# 210) Just retrieved weather for arraial do cabo (ID 3471451).
# 211) Just retrieved weather for banda aceh (ID 1215502).
# 212) Just retrieved weather for cidreira (ID 3466165).
# 213) Just retrieved weather for mae sai (ID 1152194).
# 214) Just retrieved weather for belomorsk (ID 577922).
# 215) Just retrieved weather for najran (ID 103630).
# 216) Just retrieved weather for yaqui (ID 3979975).
# 217) Just retrieved weather for santa fe (ID 3836277).
# 218) Just retrieved weather for penzance (ID 2640377).
# 219) Just retrieved weather for yulara (ID 6355222).
# 220) Just retrieved weather for murray bridge (ID 2065176).
# 221) Just retrieved weather for hermanus (ID 3366880).
# 222) Just retrieved weather for ostrovnoy (ID 556268).
# 223) Couldn't retrieve weather for bur gabo (HTTP Error 404: Not Found).
# 224) Just retrieved weather for binga (ID 895057).
# 225) Just retrieved weather for kruisfontein (ID 986717).
# 226) Just retrieved weather for cherskiy (ID 2126199).
# 227) Couldn't retrieve weather for ardistan (HTTP Error 404: Not Found).
# 228) Just retrieved weather for nazarovo (ID 1497951).
# 229) Just retrieved weather for chamba (ID 1274848).
# 230) Couldn't retrieve weather for samusu (HTTP Error 404: Not Found).
# 231) Couldn't retrieve weather for hlotse (HTTP Error 404: Not Found).
# 232) Just retrieved weather for colares (ID 2269142).
# 233) Couldn't retrieve weather for cazaje (HTTP Error 404: Not Found).
# 234) Couldn't retrieve weather for grand river south east (HTTP Error 404: Not Found).
# 235) Couldn't retrieve weather for taipao (HTTP Error 404: Not Found).
# 236) Just retrieved weather for ankara (ID 323786).
# 237) Just retrieved weather for dudinka (ID 1507116).
# 238) Just retrieved weather for kaitangata (ID 2208248).
# 239) Just retrieved weather for rawson (ID 3839307).
# 240) Just retrieved weather for portland (ID 4975802).
# 241) Just retrieved weather for carutapera (ID 3402648).
# 242) Just retrieved weather for xihua (ID 1789427).
# 243) Just retrieved weather for yar-sale (ID 1486321).
# 244) Couldn't retrieve weather for amderma (HTTP Error 404: Not Found).
# 245) Couldn't retrieve weather for taolanaro (HTTP Error 404: Not Found).
# 246) Just retrieved weather for lubango (ID 3347762).
# 247) Couldn't retrieve weather for illoqqortoormiut (HTTP Error 404: Not Found).
# 248) Just retrieved weather for ouesso (ID 2255564).
# 249) Just retrieved weather for whitehorse (ID 6180550).
# 250) Just retrieved weather for pochutla (ID 3517970).
# 251) Just retrieved weather for plattsburgh (ID 5131692).
# 252) Just retrieved weather for ancud (ID 3899695).
# 253) Just retrieved weather for husavik (ID 5961417).
# 254) Couldn't retrieve weather for bengkulu (HTTP Error 404: Not Found).
# 255) Just retrieved weather for vagur (ID 2610806).
# 256) Just retrieved weather for muisne (ID 3653967).
# 257) Just retrieved weather for belmonte (ID 8010472).
# 258) Just retrieved weather for lebu (ID 344979).
# 259) Just retrieved weather for farafangana (ID 1065158).
# 260) Just retrieved weather for vestmannaeyjar (ID 3412093).
# 261) Just retrieved weather for nago (ID 3172402).
# 262) Just retrieved weather for kidal (ID 2455290).
# 263) Just retrieved weather for gandai (ID 1271734).
# 264) Just retrieved weather for hervey bay (ID 2146219).
# 265) Just retrieved weather for bukachacha (ID 2026023).
# 266) Just retrieved weather for kodiak (ID 4407665).
# 267) Just retrieved weather for jaciara (ID 3460355).
# 268) Just retrieved weather for sabha (ID 2212775).
# 269) Just retrieved weather for cabo san lucas (ID 3985710).
# 270) Just retrieved weather for vardo (ID 4372777).
# 271) Just retrieved weather for saint anthony (ID 5606187).
# 272) Just retrieved weather for caucaia (ID 3402429).
# 273) Just retrieved weather for karaton (ID 1630058).
# 274) Couldn't retrieve weather for aakirkeby (HTTP Error 404: Not Found).
# 275) Just retrieved weather for basirhat (ID 1277950).
# 276) Just retrieved weather for naze (ID 2337542).
# 277) Just retrieved weather for hammerfest (ID 779683).
# 278) Just retrieved weather for los llanos de aridane (ID 2514651).
# 279) Just retrieved weather for san policarpo (ID 1688696).
# 280) Just retrieved weather for barra do corda (ID 3406318).
# 281) Just retrieved weather for verkhoturye (ID 1487219).
# 282) Just retrieved weather for kalianget (ID 1621395).
# 283) Just retrieved weather for longyearbyen (ID 2729907).
# 284) Just retrieved weather for saint-augustin (ID 6138501).
# 285) Just retrieved weather for arlit (ID 2447513).
# 286) Just retrieved weather for te anau (ID 2181625).
# 287) Just retrieved weather for college (ID 5859699).
# 288) Just retrieved weather for coihaique (ID 3894426).
# 289) Just retrieved weather for port lincoln (ID 2063036).
# 290) Just retrieved weather for kishtwar (ID 1266475).
# 291) Just retrieved weather for biskamzha (ID 1510030).
# 292) Just retrieved weather for batagay-alyta (ID 2027042).
# 293) Just retrieved weather for ucluelet (ID 6171633).
# 294) Just retrieved weather for leczna (ID 766583).
# 295) Just retrieved weather for kungurtug (ID 1501377).
# 296) Just retrieved weather for sakaraha (ID 1057095).
# 297) Just retrieved weather for muros (ID 3115824).
# 298) Just retrieved weather for cuencame (ID 4012344).
# 299) Just retrieved weather for pryazha (ID 504409).
# 300) Just retrieved weather for port hardy (ID 6111862).
# 301) Just retrieved weather for donghai (ID 1549542).
# 302) Just retrieved weather for berdigestyakh (ID 2026861).
# 303) Just retrieved weather for lac du bonnet (ID 6014443).
# 304) Just retrieved weather for komsomolskiy (ID 1486910).
# 305) Just retrieved weather for namatanai (ID 2090021).
# 306) Just retrieved weather for chupa (ID 3931275).
# 307) Just retrieved weather for mount isa (ID 2065594).
# 308) Just retrieved weather for sibolga (ID 1213855).
# 309) Just retrieved weather for port blair (ID 1259385).
# 310) Just retrieved weather for kalabo (ID 915471).
# 311) Just retrieved weather for dhidhdhoo (ID 1337612).
# 312) Couldn't retrieve weather for kuche (HTTP Error 404: Not Found).
# 313) Just retrieved weather for jasper (ID 4069659).
# 314) Just retrieved weather for hami (ID 1529484).
# 315) Just retrieved weather for atambua (ID 1651103).
# 316) Couldn't retrieve weather for bolshiye uki (HTTP Error 404: Not Found).
# 317) Just retrieved weather for ola (ID 2122574).
# 318) Just retrieved weather for meadow lake (ID 6071421).
# 319) Just retrieved weather for semey (ID 1519422).
# 320) Just retrieved weather for kushima (ID 1895695).
# 321) Just retrieved weather for namibe (ID 3347019).
# 322) Just retrieved weather for agadez (ID 2448085).
# 323) Just retrieved weather for solnechnyy (ID 2016307).
# 324) Couldn't retrieve weather for disna (HTTP Error 404: Not Found).
# 325) Just retrieved weather for dengzhou (ID 1812990).
# 326) Just retrieved weather for ahipara (ID 2194098).
# 327) Just retrieved weather for kyren (ID 2021031).
# 328) Just retrieved weather for flinders (ID 6255012).
# 329) Just retrieved weather for krasnokholmskiy (ID 542965).
# 330) Just retrieved weather for sao jose da coroa grande (ID 3388456).
# 331) Just retrieved weather for nantucket (ID 4944903).
# 332) Just retrieved weather for inhambane (ID 1045114).
# 333) Just retrieved weather for torbay (ID 6167817).
# 334) Just retrieved weather for songea (ID 877401).
# 335) Couldn't retrieve weather for raga (HTTP Error 404: Not Found).
# 336) Just retrieved weather for kununurra (ID 2068110).
# 337) Just retrieved weather for hobyo (ID 57000).
# 338) Just retrieved weather for luena (ID 3347719).
# 339) Just retrieved weather for nhulunbuy (ID 2064735).
# 340) Just retrieved weather for lata (ID 1253628).
# 341) Just retrieved weather for poyarkovo (ID 2017705).
# 342) Just retrieved weather for narok (ID 184379).
# 343) Just retrieved weather for waycross (ID 4229763).
# 344) Just retrieved weather for bandarbeyla (ID 64814).
# 345) Just retrieved weather for atar (ID 2381334).
# 346) Just retrieved weather for mehamn (ID 778707).
# 347) Just retrieved weather for marawi (ID 1701054).
# 348) Just retrieved weather for monrovia (ID 2274895).
# 349) Couldn't retrieve weather for haibowan (HTTP Error 404: Not Found).
# 350) Just retrieved weather for petatlan (ID 3992842).
# 351) Just retrieved weather for djougou (ID 2394560).
# 352) Just retrieved weather for kerman (ID 128234).
# 353) Just retrieved weather for tual (ID 1623197).
# 354) Just retrieved weather for tonder (ID 2611497).
# 355) Just retrieved weather for karpogory (ID 552256).
# 356) Just retrieved weather for dorado (ID 4564133).
# 357) Just retrieved weather for suntar (ID 2015913).
# 358) Just retrieved weather for mafra (ID 3458147).
# 359) Just retrieved weather for bilibino (ID 2126682).
# 360) Just retrieved weather for imeni poliny osipenko (ID 2023584).
# 361) Just retrieved weather for hay river (ID 5972762).
# 362) Just retrieved weather for udachnyy (ID 2014624).
# 363) Just retrieved weather for les trois-ilets (ID 3570396).
# 364) Just retrieved weather for nuuk (ID 3421319).
# 365) Just retrieved weather for aklavik (ID 5882953).
# 366) Just retrieved weather for tautira (ID 4033557).
# 367) Just retrieved weather for honningsvag (ID 779554).
# 368) Just retrieved weather for krasnopavlivka (ID 704363).
# 369) Just retrieved weather for ust-kuyga (ID 2013921).
# 370) Just retrieved weather for zhigansk (ID 2012530).
# 371) Just retrieved weather for meulaboh (ID 1214488).
# 372) Just retrieved weather for pangai (ID 4032369).
# 373) Just retrieved weather for nouadhibou (ID 2377457).
# 374) Just retrieved weather for santa isabel (ID 3996069).
# 375) Just retrieved weather for salalah (ID 286621).
# 376) Just retrieved weather for geraldton (ID 5960603).
# 377) Just retrieved weather for lensk (ID 2020838).
# 378) Just retrieved weather for ligayan (ID 1706466).
# 379) Just retrieved weather for tasiilaq (ID 3424607).
# 380) Just retrieved weather for santa cruz de la palma (ID 2511180).
# 381) Just retrieved weather for ondjiva (ID 3346821).
# 382) Just retrieved weather for belen (ID 5456975).
# 383) Just retrieved weather for vadso (ID 777073).
# 384) Just retrieved weather for pisco (ID 3932145).
# 385) Just retrieved weather for mokrin (ID 787857).
# 386) Just retrieved weather for san benito (ID 3685961).
# 387) Just retrieved weather for qaqortoq (ID 3420846).
# 388) Just retrieved weather for qasigiannguit (ID 3420768).
# 389) Just retrieved weather for pula (ID 3658053).
# 390) Just retrieved weather for mimongo (ID 2398430).
# 391) Couldn't retrieve weather for samalaeulu (HTTP Error 404: Not Found).
# 392) Just retrieved weather for crotone (ID 2524881).
# 393) Just retrieved weather for livingston (ID 5100572).
# 394) Just retrieved weather for buraydah (ID 107304).
# 395) Just retrieved weather for morant bay (ID 3489440).
# 396) Just retrieved weather for muravlenko (ID 1540711).
# 397) Just retrieved weather for houston (ID 4699066).
# 398) Just retrieved weather for cordoba (ID 3846616).
# 399) Just retrieved weather for pitimbu (ID 3391889).
# 400) Just retrieved weather for svetlaya (ID 2015852).
# 401) Just retrieved weather for sorong (ID 1626542).
# 402) Just retrieved weather for chara (ID 262462).
# 403) Just retrieved weather for orlik (ID 3102488).
# 404) Just retrieved weather for camacha (ID 2270385).
# 405) Couldn't retrieve weather for sentyabrskiy (HTTP Error 404: Not Found).
# 406) Just retrieved weather for rundu (ID 3353383).
# 407) Just retrieved weather for batagay (ID 2027044).
# 408) Just retrieved weather for fare (ID 4034496).
# 409) Just retrieved weather for moyale (ID 186180).
# 410) Just retrieved weather for ilulissat (ID 3423146).
# 411) Just retrieved weather for lang son (ID 1576633).
# 412) Just retrieved weather for konstantinovka (ID 617239).
# 413) Just retrieved weather for takoradi (ID 2294915).
# 414) Couldn't retrieve weather for ipora (HTTP Error 404: Not Found).
# 415) Just retrieved weather for tomatlan (ID 3981391).
# 416) Just retrieved weather for qingdao (ID 1797929).
# 417) Just retrieved weather for warud (ID 1252919).
# 418) Just retrieved weather for esqueda (ID 4006532).
# 419) Just retrieved weather for moose factory (ID 6078372).
# 420) Just retrieved weather for puerto escondido (ID 3520994).
# 421) Just retrieved weather for nokaneng (ID 933211).
# 422) Just retrieved weather for lavrentiya (ID 4031637).
# 423) Just retrieved weather for fort-shevchenko (ID 609906).
# 424) Just retrieved weather for kiruna (ID 605155).
# 425) Just retrieved weather for gwadar (ID 1177446).
# 426) Just retrieved weather for bundaberg (ID 2173323).
# 427) Just retrieved weather for whakatane (ID 2208330).
# 428) Just retrieved weather for pahrump (ID 5509851).
# 429) Couldn't retrieve weather for bargal (HTTP Error 404: Not Found).
# 430) Just retrieved weather for abha (ID 110690).
# 431) Just retrieved weather for yeniseysk (ID 1485997).
# 432) Just retrieved weather for padang (ID 1633419).
# 433) Just retrieved weather for tazovskiy (ID 1489853).
# 434) Just retrieved weather for bay roberts (ID 5895424).
# 435) Just retrieved weather for ha giang (ID 1581349).
# 436) Just retrieved weather for arman (ID 2127060).
# 437) Couldn't retrieve weather for tartus (HTTP Error 404: Not Found).
# 438) Just retrieved weather for buala (ID 2109528).
# 439) Just retrieved weather for omboue (ID 2396853).
# 440) Just retrieved weather for carmo do paranaiba (ID 3466902).
# 441) Just retrieved weather for palmer (ID 2067070).
# 442) Just retrieved weather for kutum (ID 371745).
# 443) Just retrieved weather for sao domingos (ID 3449293).
# 444) Just retrieved weather for saint-georges (ID 6295855).
# 445) Just retrieved weather for ust-maya (ID 2013918).
# 446) Just retrieved weather for mangrol (ID 1263751).
# 447) Just retrieved weather for richards bay (ID 962367).
# 448) Just retrieved weather for graciano sanchez (ID 3527413).
# 449) Just retrieved weather for ongandjera (ID 3354178).
# 450) Just retrieved weather for saint-pierre (ID 2995603).
# 451) Just retrieved weather for eston (ID 5949601).
# 452) Just retrieved weather for russell (ID 4278471).
# 453) Just retrieved weather for tabou (ID 2281120).
# 454) Just retrieved weather for port keats (ID 2063039).
# 455) Just retrieved weather for north bend (ID 5742974).
# 456) Just retrieved weather for cabatuan (ID 1721714).
# 457) Just retrieved weather for kitimat (ID 5993072).
# 458) Just retrieved weather for graham (ID 4694420).
# 459) Just retrieved weather for jashpurnagar (ID 1269177).
# 460) Just retrieved weather for hakkari (ID 634964).
# 461) Couldn't retrieve weather for kamenskoye (HTTP Error 404: Not Found).
# 462) Just retrieved weather for xingyi (ID 1787599).
# 463) Just retrieved weather for vanimo (ID 2084442).
# 464) Couldn't retrieve weather for warqla (HTTP Error 404: Not Found).
# 465) Just retrieved weather for bara (ID 2347758).
# 466) Just retrieved weather for brae (ID 2654970).
# 467) Just retrieved weather for yinchuan (ID 1786657).
# 468) Just retrieved weather for merauke (ID 2082539).
# 469) Just retrieved weather for duku (ID 1632237).
# 470) Just retrieved weather for bubaque (ID 2374583).
# 471) Just retrieved weather for havelock (ID 4470244).
# 472) Just retrieved weather for porbandar (ID 1259395).
# 473) Just retrieved weather for orange cove (ID 5379533).
# 474) Just retrieved weather for beyneu (ID 610298).
# 475) Couldn't retrieve weather for miahuatlan (HTTP Error 404: Not Found).
# 476) Just retrieved weather for varzea da palma (ID 3445459).
# 477) Just retrieved weather for gumdag (ID 161943).
# 478) Just retrieved weather for sitka (ID 4267710).
# 479) Just retrieved weather for tilichiki (ID 2120591).
# 480) Couldn't retrieve weather for lolua (HTTP Error 404: Not Found).
# 481) Just retrieved weather for vila (ID 3164565).
# 482) Just retrieved weather for manali (ID 1263967).
# 483) Couldn't retrieve weather for attawapiskat (HTTP Error 404: Not Found).
# 484) Just retrieved weather for tura (ID 2014833).
# 485) Just retrieved weather for kon tum (ID 1578500).
# 486) Just retrieved weather for watsa (ID 204283).
# 487) Couldn't retrieve weather for grand centre (HTTP Error 404: Not Found).
# 488) Couldn't retrieve weather for palasa (HTTP Error 404: Not Found).
# 489) Just retrieved weather for tsiroanomandidy (ID 1054463).
# 490) Just retrieved weather for zlobin (ID 3191648).
# 491) Just retrieved weather for troitsko-pechorsk (ID 481548).
# 492) Just retrieved weather for pandharpur (ID 1260546).
# 493) Just retrieved weather for gladstone (ID 2165478).
# 494) Just retrieved weather for sancti spiritus (ID 3540667).
# 495) Just retrieved weather for dingle (ID 1714733).
# 496) Just retrieved weather for dayong (ID 1789289).
# 497) Just retrieved weather for ulaangom (ID 1515029).
# 498) Just retrieved weather for slave lake (ID 6149374).
# 499) Just retrieved weather for linqiong (ID 1803365).
# 500) Just retrieved weather for lixourion (ID 258175).
# 501) Just retrieved weather for cotonou (ID 2394819).
# 502) Just retrieved weather for tupik (ID 2014836).
# 503) Just retrieved weather for lagoa (ID 2267254).
# 504) Just retrieved weather for la palma (ID 3687505).
# 505) Just retrieved weather for maniitsoq (ID 3421982).
# 506) Couldn't retrieve weather for palabuhanratu (HTTP Error 404: Not Found).
# 507) Just retrieved weather for mont-joli (ID 6944113).
# 508) Just retrieved weather for oildale (ID 5378870).
# 509) Just retrieved weather for kabare (ID 216281).
# 510) Just retrieved weather for muhos (ID 645765).
# 511) Just retrieved weather for sale (ID 2150615).
# 512) Just retrieved weather for koumac (ID 2140558).
# 513) Just retrieved weather for milkovo (ID 727030).
# 514) Just retrieved weather for laguna (ID 3581398).
# 515) Just retrieved weather for bolobo (ID 2316748).
# 516) Just retrieved weather for cervo (ID 3469169).
# 517) Just retrieved weather for abu dhabi (ID 292968).
# 518) Couldn't retrieve weather for karkaralinsk (HTTP Error 404: Not Found).
# 519) Couldn't retrieve weather for doctor pedro p. pena (HTTP Error 404: Not Found).
# 520) Just retrieved weather for mokhotlong (ID 932416).
# 521) Just retrieved weather for kijang (ID 1842966).
# 522) Just retrieved weather for kotelnikovo (ID 543728).
# 523) Just retrieved weather for zamora (ID 3104342).
# 524) Just retrieved weather for orangeburg (ID 4590184).
# 525) Couldn't retrieve weather for mrirt (HTTP Error 404: Not Found).
# 526) Just retrieved weather for riberalta (ID 3906466).
# 527) Just retrieved weather for hajnowka (ID 771158).
# 528) Just retrieved weather for port hedland (ID 2063042).
# 529) Just retrieved weather for chapais (ID 5919850).
# 530) Just retrieved weather for the pas (ID 6164499).
# 531) Just retrieved weather for kiama (ID 2161515).
# 532) Just retrieved weather for westport (ID 4845585).
# 533) Couldn't retrieve weather for alotau (HTTP Error 404: Not Found).
# 534) Just retrieved weather for doha (ID 290030).
# 535) Just retrieved weather for atherton (ID 2177541).
# 536) Just retrieved weather for kirksville (ID 5055787).
# 537) Just retrieved weather for biak (ID 1637001).
# 538) Just retrieved weather for vanavara (ID 2013727).
# 539) Just retrieved weather for dong hoi (ID 1582886).
# 540) Just retrieved weather for boguchany (ID 1509844).
# 541) Just retrieved weather for johnstown (ID 5195561).
# 542) Just retrieved weather for grand-santi (ID 3381538).
# 543) Couldn't retrieve weather for shchelyayur (HTTP Error 404: Not Found).
# 544) Just retrieved weather for prince rupert (ID 6113406).
# 545) Just retrieved weather for caravelas (ID 3466980).
# 546) Just retrieved weather for aswan (ID 359792).
# 547) Just retrieved weather for sao joao batista (ID 3397893).
# 548) Just retrieved weather for saryg-sep (ID 1492948).
# 549) Just retrieved weather for entre rios (ID 3464100).
# 550) Couldn't retrieve weather for ketchenery (HTTP Error 404: Not Found).
# 551) Couldn't retrieve weather for toliary (HTTP Error 404: Not Found).
# 552) Just retrieved weather for ambon (ID 3037899).
# 553) Couldn't retrieve weather for ciras (HTTP Error 404: Not Found).
# 554) Just retrieved weather for kalmunai (ID 1242110).
# 555) Just retrieved weather for codrington (ID 2160063).
# 556) Just retrieved weather for obo (ID 236950).
# 557) Just retrieved weather for kaohsiung (ID 1673820).
# 558) Just retrieved weather for solano (ID 3667868).
# 559) Just retrieved weather for almeirim (ID 3407903).
# 560) Just retrieved weather for george town (ID 1735106).
# 561) Just retrieved weather for kochki (ID 1503061).
# 562) Just retrieved weather for zaraza (ID 3625066).
# 563) Just retrieved weather for constitucion (ID 4011743).
# 564) Just retrieved weather for agdam (ID 148619).
# 565) Just retrieved weather for alice (ID 1023332).
# 566) Just retrieved weather for inongo (ID 2315417).
# 567) Just retrieved weather for san jose (ID 3602137).
# 568) Just retrieved weather for dongsheng (ID 1788268).
# 569) Just retrieved weather for khilok (ID 2022463).
# 570) Just retrieved weather for seymchan (ID 2121373).
# 571) Just retrieved weather for sangar (ID 2017215).
# 572) Just retrieved weather for voh (ID 2137748).
# 573) Just retrieved weather for vao (ID 588365).
# 574) Couldn't retrieve weather for khristoforovo (HTTP Error 404: Not Found).
# 575) Just retrieved weather for altamira (ID 3407882).
# 576) Just retrieved weather for marquette (ID 5000947).
# 577) Couldn't retrieve weather for dipkarpaz (HTTP Error 404: Not Found).
# 578) Just retrieved weather for sao lourenco da mata (ID 3388376).
# 579) Just retrieved weather for esil (ID 1524296).
# 580) Just retrieved weather for poum (ID 787487).
# 581) Just retrieved weather for coahuayana (ID 3981460).
# 582) Just retrieved weather for ambilobe (ID 1082243).
# 583) Just retrieved weather for kudahuvadhoo (ID 1337607).
# 584) Couldn't retrieve weather for bobo dioulasso (HTTP Error 404: Not Found).
# 585) Just retrieved weather for maues (ID 3395062).
# 586) Just retrieved weather for umm kaddadah (ID 364933).
# 587) Just retrieved weather for henties bay (ID 3356832).

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
dfCityWthr = pd.DataFrame(columns=['ID', 'Name', 'Country', 'Lat', 'Lng', 'CurrCond', 'TempF'])
i = 0
for var in lstCityWthr:
    if var != '#N/A':
        dfCityWthr.loc[i] = [var['id'], var['name'], var['sys']['country'], var['coord']['lat'], \
                             var['coord']['lon'], var['weather'][0]['main'], var['main']['temp']]
        i += 1

# %%
dfCityWthr.head()
# Out:
#         ID            Name Country    Lat     Lng CurrCond  TempF
# 0  2075265       Busselton      AU -33.64  115.35   Clouds  51.01
# 1  1283285           Jumla      NP  29.28   82.18     Rain  68.09
# 2  3372707  Ribeira Grande      PT  38.52  -28.70   Clouds  71.60
# 3  3461425        Ilhabela      BR -23.78  -45.36   Clouds  73.49
# 4   934322       Mahebourg      MU -20.41   57.70   Clouds  74.05

# %%
dfCityWthr.to_csv('City Weather.csv')

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
